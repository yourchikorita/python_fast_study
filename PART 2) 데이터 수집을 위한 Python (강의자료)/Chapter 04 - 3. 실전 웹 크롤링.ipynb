# %% [markdown]
# ### 학습목표
#  - 1. 다음 뉴스와 그 뉴스의 댓글 크롤링하기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### 뉴스 제목 크롤링

# %%
def get_daum_news_title(news_id):
    url = 'https://news.v.daum.net/v/{}'.format(news_id)
    resp = requests.get(url)
    
    soup = BeautifulSoup(resp.text)
    
    title_tag = soup.select_one('h3.tit_view')
    if title_tag:
        return title_tag.get_text()
    return ""

# %%
get_daum_news_title('20190728165812603')
# Out:
# '일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"'

# %%
get_daum_news_title('20190801114158041')
# Out:
# '5G 2∼3위 경쟁 치열..LGU+, 6월 가입자 순증 KT 앞서'

# %% [markdown]
# #### 뉴스 본문 크롤링

# %%
def get_daum_news_content(news_id):
    url = 'https://news.v.daum.net/v/{}'.format(news_id)
    resp = requests.get(url)
    
    soup = BeautifulSoup(resp.text)
    
    content = ''
    for p in soup.select('div#harmonyContainer p'):
        content += p.get_text()
    return content

# %%
get_daum_news_content('20190728165812603')
# Out:
# '[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.27일(현지시간) 더버지 등 주요 외신들에 따르면 머스크 CEO는 자신의 트위터를 통해 이 같은 계획을 밝혔다. 그는 "자동차가 정차했을 때 넷플릭스와 유튜브를 감상할 수 있는 기능이 조만간 추가될 것"이라며 "편안한 좌석과 서라운드 사운드 오디오를 통해 영화관과 같은 느낌을 받을 수 있을 것"이라고 강조했다.테슬라가 이처럼 콘텐츠 방면으로 확장하려 든 것은 이번이 처음이 아니다. 지난달 세계 최대 게임쇼 E3에서는 이미 운전자가 \'폴아웃 쉘터\'라는 게임을 할 수 있을 것이라고 발표한 바 있다. 이후에도 최근 게임업체 아타리사(社)의 자동차 경주 게임 ‘폴포지션’, 슈팅게임 ‘템페스트’, ‘미사일커맨드’ 등 고전 게임을 제공하기도 했다. 운전대로 게임을 조작하는 방식으로, 차가 주차돼 있을 경우에만 즐길 수 있다.이번 영상 콘텐츠는 주행 중에도 감상할 수 있도록 하는 방안을 고려하고 있다. 테슬라 측은 규제당국이 자율주행에 대해 완전히 승인하면 차량이 움직일 때에도 승객이 동영상을 즐길 수 있을 것이라고 설명했다.하지만 아직까지 자율주행차의 안전에 대한 우려는 완전히 걷혀지지 않은 상황이다. 지난 2017년 차량공유 서비스 우버의 자율주행 시범차량이 보행자와 충돌한 사고가 발생한 바 있다. 게다가 당시 시험 운전자는 디즈니의 동영상 스트리밍 서비스인 \'훌루\'를 이용하고 있던 것으로 밝혀졌다.이민우 기자 letzwin@asiae.co.kr'

# %%
get_daum_news_content('20190801114158041')

# %% [markdown]
# #### 뉴스 댓글 크롤링

# %%
#401 에러 나오면 헤어추가
url = 'https://comment.daum.net/apis/v1/posts/@20190829173924655/comments?parentId=0&offset=13&limit=10&sort=RECOMMEND&isInitial=false'
headers = {
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJncmFudF90eXBlIjoiYWxleF9jcmVkZW50aWFscyIsInNjb3BlIjpbXSwiZXhwIjoxNTY3MTIzMDc0LCJhdXRob3JpdGllcyI6WyJST0xFX0NMSUVOVCJdLCJqdGkiOiJkMjg1YTFiOS00MGEzLTQ4NTMtYjFlYS00NTNkYzZmOTk4YWEiLCJjbGllbnRfaWQiOiIyNkJYQXZLbnk1V0Y1WjA5bHI1azc3WTgifQ.nMUD_dvO6AYtl3rjsqeCDUhhoXlFbnXwkRspDKUyJDs',
        'Referer': 'https://news.v.daum.net/v/20190829173924655',
        'Sec-Fetch-Mode':'cors',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}
resp = requests.get(url, headers=headers)
resp.json()
# Out:
# [{'id': 408884811,
#   'userId': -83240665,
#   'postId': 134406076,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
#   'content': '댓글 웃긴다. 저게 피해자를 비난하는 거니 한국을 돌려서 비난하고 적국이라잖아. 바라는  바야. 왜놈들 핏줄이 어디가겠니~~!!',
#   'createdAt': '2019-08-29T18:09:49+0900',
#   'updatedAt': '2019-08-29T18:09:49+0900',
#   'childCount': 1,
#   'likeCount': 65,
#   'dislikeCount': 5,
#   'recommendCount': 60,
#   'user': {'id': -83240665,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://t1.daumcdn.net/profile/p3nJBqTeMs50',
#    'url': '',
#    'username': 'DAUM:5DgHn',
#    'roles': 'ROLE_USER,ROLE_DAUM',
#    'providerId': 'DAUM',
#    'providerUserId': '5DgHn',
#    'displayName': 'jung',
#    'commentCount': 166}},
#  {'id': 408885543,
#   'userId': -104262986,
#   'postId': 134406076,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
# ...

# %%
def get_daum_news_comments(news_id):
    headers = {
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJncmFudF90eXBlIjoiYWxleF9jcmVkZW50aWFscyIsInNjb3BlIjpbXSwiZXhwIjoxNTY3MTIzMDc0LCJhdXRob3JpdGllcyI6WyJST0xFX0NMSUVOVCJdLCJqdGkiOiJkMjg1YTFiOS00MGEzLTQ4NTMtYjFlYS00NTNkYzZmOTk4YWEiLCJjbGllbnRfaWQiOiIyNkJYQXZLbnk1V0Y1WjA5bHI1azc3WTgifQ.nMUD_dvO6AYtl3rjsqeCDUhhoXlFbnXwkRspDKUyJDs',
        'Referer': 'https://news.v.daum.net/v/20190829173924655',
        'Sec-Fetch-Mode':'cors',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}
    
    url_template = 'https://comment.daum.net/apis/v1/posts/@{}/comments?parentId=0&offset={}&limit=10&sort=RECOMMEND&isInitial=false'
    offset = 0
    comments = []
    while True:
        url = url_template.format(news_id, offset)
        resp = requests.get(url, headers=headers)
        data = resp.json()
        if not data:
            break
            
        comments.extend(data)
        offset += 10
        
    return comments

# %%
len(get_daum_news_comments('20190728165812603'))
# Out:
# 36

# %%
get_daum_news_comments('20190728165812603')
# Out:
# [{'id': 393659258,
#   'userId': 16260090,
#   'postId': 133493400,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 0,
#   'content': '세상은 이렇게 빠르게 발전하는데\n친일매국매독임질/ 자한당은 \n구석기 그대로구나\n오호~  통제라...\n내년 총선은 \n무조건 한알전이다\n친일매국노들을 찍는\n개돼지쌔끼들은\n무조건 친일파다\n이제껏 못찍은것은 용서할테니\n잘하자!!!!!!',
#   'createdAt': '2019-07-28T17:11:44+0900',
#   'updatedAt': '2019-07-28T17:11:44+0900',
#   'childCount': 2,
#   'likeCount': 73,
#   'dislikeCount': 21,
#   'recommendCount': 52,
#   'user': {'id': 16260090,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://t1.daumcdn.net/profile/ta7n73vVZvs0',
#    'url': '',
#    'username': 'DAUM:CD7np',
#    'roles': 'ROLE_USER,ROLE_DAUM',
#    'providerId': 'DAUM',
#    'providerUserId': 'CD7np',
#    'displayName': '늘푸르른 소나무',
#    'commentCount': 98}},
#  {'id': 393666979,
#   'userId': -40118895,
#   'postId': 133493400,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
# ...

# %%
len(get_daum_news_comments('20190801114158041'))
